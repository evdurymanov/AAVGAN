# %%
from Bio.SeqIO.FastaIO import SimpleFastaParser
from Bio.pairwise2 import format_alignment
from Bio import pairwise2
from tqdm import tqdm

# %%
gen_capsid_0 = []
gen_capsid_1 = []
_1_37 = []
_1_36 = []
gen_zeros = []
gen_ones = []

# %%
with open("generated_19000_20_03_53.fasta") as in_handle:
    for title, seq in SimpleFastaParser(in_handle):
        gen_capsid_0.append(seq)

# %%
with open("generated_19000_20_04_40.fasta") as in_handle:
    for title, seq in SimpleFastaParser(in_handle):
        gen_capsid_1.append(seq)

# %%
with open("train_sequences.fasta") as in_handle:
    for title, seq in SimpleFastaParser(in_handle):
        _1_37.append(seq)

# %%
with open("uniprot-ec 1.1.1.36.fasta") as in_handle:
    for title, seq in SimpleFastaParser(in_handle):
        _1_36.append(seq)

# %%
with open("zeros.fasta") as in_handle:
    for title, seq in SimpleFastaParser(in_handle):
        gen_zeros.append(seq)

# %%
with open("ones.fasta") as in_handle:
    for title, seq in SimpleFastaParser(in_handle):
        gen_ones.append(seq)

# %%
print(len(gen_capsid_0), len(gen_capsid_1), len(_1_37), len(_1_36))
# Out:
# 128 128 16706 4738

# %%
for gen in gen_capsid_0:
    aligments = []
    for seq_1_37 in _1_37:
        a = pairwise2.align.globalxx(gen, seq_1_37, score_only = True)
        aligments.append(a)
    print(max(aligments), sum(aligments)/len(aligments))
# Out:
# 136.0 114.00071830480067
# 139.0 118.90973303004908
# 131.0 113.33862085478272
# 138.0 118.15491440201126
# 132.0 113.73213216808333
# 136.0 117.80240632108224
# 137.0 118.30551897521849
# 141.0 125.41404285885311
# 139.0 122.46971148090506
# 118.0 101.15275948760925
# 138.0 120.58164731234287
# 136.0 115.07913324554052
# 138.0 117.49688734586375
# 99.0 84.75433975817072
# 141.0 115.89321201963367
# 137.0 116.14671375553694
# 135.0 115.66784388842332
# 140.0 118.11229498383814
# 128.0 108.97599664791093
# 137.0 117.77469172752305
# 137.0 115.2572728361068
# 136.0 117.97444032084282
# 139.0 117.84328983598706
# 129.0 109.54579193104274
# 139.0 116.58033042020831
# 130.0 111.36130731473722
# 141.0 116.68352687657129
# 141.0 121.01729917394948
# 141.0 119.20992457799593
# 140.0 122.55183766311505
# 137.0 118.63474200885909
# 136.0 116.4262540404645
# 140.0 116.82712797797198
# 144.0 124.72883993774691
# 136.0 116.47013049203879
# 134.0 110.9712079492398
# 132.0 113.49311624566025
# ...

# %%
for gen in gen_capsid_0:
    aligments = []
    for seq_1_36 in _1_36:
        a = pairwise2.align.globalxx(gen, seq_1_36, score_only = True)
        aligments.append(a)
    print(max(aligments), sum(aligments)/len(aligments))
# Out:
# 136.0 116.23364288729422
# 142.0 114.17855635289152
# 127.0 103.9476572393415
# 148.0 123.00084423807513
# 134.0 116.15934993668215
# 157.0 129.31152384972563
# 139.0 108.77163360067539
# 133.0 111.64394259181088
# 150.0 121.10194174757281
# 121.0 86.89341494301392
# 134.0 101.4504010130857
# 133.0 97.97804981004643
# 154.0 128.5576192486281
# 94.0 74.73575348248205
# 155.0 124.82397636133389
# 135.0 101.92169691853103
# 134.0 109.22878851836218
# 144.0 120.14056563951034
# 122.0 95.19501899535669
# 137.0 111.31468974250738
# 166.0 121.36471084845927
# 132.0 103.65217391304348
# 160.0 127.20873786407768
# 132.0 112.01941747572816
# 141.0 122.13296749683411
# 137.0 117.63613338961588
# 168.0 129.76931194596875
# 138.0 107.40966652596032
# 153.0 128.0120303925707
# 135.0 103.76255804136767
# 148.0 120.39341494301392
# 130.0 103.27923174335163
# 172.0 133.39700295483325
# 136.0 106.0578303081469
# 137.0 107.77078936260025
# 129.0 99.57239341494301
# 133.0 110.11059518784297
# ...

# %%
for gen in gen_capsid_1:
    aligments = []
    for seq_1_37 in _1_37:
        a = pairwise2.align.globalxx(gen, seq_1_37, score_only = True)
        aligments.append(a)
    print(max(aligments), sum(aligments)/len(aligments))
# Out:
# 123.0 104.36878965641087
# 124.0 107.57081288159942
# 123.0 108.53968634023704
# 120.0 105.8215012570334
# 128.0 109.43810606967557
# 124.0 109.7572728361068
# 128.0 108.08164731234287
# 122.0 107.21710762600263
# 126.0 108.22740332814557
# 124.0 107.37585298695079
# 125.0 107.39476834670178
# 123.0 105.59278103675327
# 132.0 109.79881479707889
# 110.0 93.3264695319047
# 126.0 107.26032563150963
# 126.0 109.35592002873219
# 124.0 107.6314497785227
# 125.0 106.93265892493714
# 127.0 109.18508320363941
# 118.0 93.17790015563271
# 122.0 107.27535017359033
# 124.0 107.64174548066563
# 122.0 106.02789416975936
# 119.0 104.07787621213934
# 127.0 108.9362504489405
# 124.0 107.68304800670418
# 128.0 107.66293547228541
# 124.0 106.5199329582186
# 128.0 108.71716748473602
# 123.0 105.349275709326
# 123.0 107.74374476236083
# 123.0 108.6590446546151
# 127.0 107.72087872620615
# 128.0 107.64210463306597
# 123.0 107.97360229857536
# 127.0 109.27529031485693
# 124.0 107.77762480545911
# ...

# %%
for gen in gen_capsid_1:
    aligments = []
    for seq_1_36 in _1_36:
        a = pairwise2.align.globalxx(gen, seq_1_36, score_only = True)
        aligments.append(a)
    print(max(aligments), sum(aligments)/len(aligments))
# Out:
# 170.0 135.57344871253693
# 199.0 146.44301392992824
# 194.0 138.61502743773744
# 166.0 129.68087800759815
# 180.0 144.3144786829886
# 178.0 139.30202617138033
# 164.0 140.67138032925286
# 150.0 130.78429717180245
# 202.0 148.1036302237231
# 180.0 130.66504854368932
# 199.0 146.8775854791051
# 169.0 138.78682988602785
# 130.0 104.50042211903757
# 108.0 83.1747572815534
# 195.0 144.13001266357114
# 191.0 147.75094976783453
# 198.0 149.3417053609118
# 190.0 147.6582946390882
# 197.0 146.4409033347404
# 112.0 81.83790628957367
# 195.0 143.29252849303504
# 210.0 141.7608695652174
# 163.0 130.39826931194597
# 141.0 121.92233009708738
# 193.0 143.55086534402702
# 192.0 143.6329674968341
# 189.0 135.76276910088646
# 197.0 143.61587167581257
# 174.0 141.14626424651752
# 154.0 123.52173913043478
# 194.0 146.51097509497677
# 194.0 146.71084845926552
# 173.0 138.50358801181935
# 131.0 110.19987336428873
# 202.0 140.90143520472773
# 130.0 100.44132545377796
# 219.0 140.5956099620093
# ...

# %%
for gen in gen_zeros:
    aligments = []
    for seq_1_37 in _1_37:
        a = pairwise2.align.globalxx(gen, seq_1_37, score_only = True)
        aligments.append(a)
    print(max(aligments), sum(aligments)/len(aligments))
# Out:
# 138.0 119.48329941338442
# 133.0 113.80785346582066
# 141.0 118.40913444271519
# 132.0 111.9817430863163
# 107.0 91.61067879803663
# 144.0 117.59373877648748
# 142.0 125.62235125104753
# 142.0 124.20040703938704
# 134.0 116.23081527594876
# 141.0 118.53142583502932
# 135.0 113.9384652220759
# 137.0 117.74913204836585
# 136.0 117.71219920986472
# 139.0 120.47683467017838
# 143.0 121.38974021309708
# 142.0 123.4218843529271
# 127.0 110.24087154315815
# 126.0 109.99802466179815
# 144.0 123.5171794564827
# 127.0 108.46336645516581
# 139.0 118.91805339399018
# 134.0 114.56105590805699
# 139.0 118.1552136956782
# 104.0 89.29061415060457
# 143.0 126.85843409553453
# 130.0 111.90548305997845
# 141.0 118.21447384173351
# 142.0 119.47312342870825
# 136.0 115.31437806776009
# 138.0 116.50263378426912
# 143.0 126.29671974141027
# 131.0 113.60235843409554
# 112.0 92.97791212737938
# 139.0 120.05471088231774
# 141.0 120.38884233209625
# 138.0 122.63348497545792
# 142.0 122.20585418412547
# ...

# %%
for gen in gen_zeros:
    aligments = []
    for seq_1_36 in _1_36:
        a = pairwise2.align.globalxx(gen, seq_1_36, score_only = True)
        aligments.append(a)
    print(max(aligments), sum(aligments)/len(aligments))
# Out:
# 134.0 100.6895314478683
# 130.0 96.9501899535669
# 160.0 127.32629801604052
# 133.0 97.72287885183621
# 106.0 81.51013085690164
# 165.0 133.4356268467708
# 139.0 104.6276910088645
# 138.0 116.79548332629801
# 134.0 102.04896580835796
# 162.0 130.69269734065006
# 138.0 100.852258336851
# 157.0 125.98902490502321
# 135.0 112.35246939636977
# 161.0 128.62009286618826
# 145.0 114.66547066272689
# 137.0 106.03503588011819
# 133.0 107.25432672013508
# 144.0 117.30899113550021
# 137.0 102.55002110595188
# 132.0 114.32376530181511
# 159.0 125.51181933305192
# 134.0 99.99493457154918
# 165.0 130.3644997889405
# 105.0 78.15766146053187
# 140.0 114.85162515829464
# 132.0 114.3818066694808
# 140.0 111.42148585901224
# 139.0 102.93583790628958
# 134.0 115.2271000422119
# 165.0 131.39721401435204
# 139.0 114.93351625158294
# 134.0 110.15238497256226
# 105.0 80.60299704516673
# 144.0 119.37040945546644
# 137.0 119.09772055719714
# 139.0 106.25770367243562
# 147.0 124.45778809624314
# ...

# %%
for gen in gen_ones:
    aligments = []
    for seq_1_37 in _1_37:
        a = pairwise2.align.globalxx(gen, seq_1_37, score_only = True)
        aligments.append(a)
    print(max(aligments), sum(aligments)/len(aligments))
# Out:
# 124.0 103.76595235244822
# 124.0 107.81946606009816
# 123.0 108.5587812761882
# 126.0 109.64958697473962
# 124.0 107.63180893092301
# 126.0 107.39961690410631
# 125.0 107.07045372919909
# 126.0 106.06997485933198
# 122.0 107.25805099964084
# 124.0 107.41087034598348
# 130.0 109.12612235125104
# 127.0 105.03986591643721
# 124.0 110.07572129773735
# 124.0 107.73404764755178
# 122.0 106.90703938704657
# 127.0 109.3502933077936
# 124.0 106.32946246857416
# 124.0 109.01316892134562
# 123.0 105.4562432658925
# 120.0 106.80456123548426
# 125.0 108.36603615467497
# 124.0 106.22848078534658
# 122.0 107.80851191188795
# 127.0 106.46103196456363
# 125.0 108.12043577157907
# 124.0 106.36765234047648
# 128.0 109.10792529630073
# 127.0 109.38896204956303
# 123.0 106.97078893810607
# 127.0 107.70088590925415
# 122.0 105.16143900395068
# 120.0 106.57620016760445
# 126.0 110.13917155512989
# 123.0 107.27121992098647
# 125.0 107.04363701664073
# 124.0 106.61875972704418
# 123.0 107.78277265653058
# ...

# %%
for gen in gen_ones:
    aligments = []
    for seq_1_36 in _1_36:
        a = pairwise2.align.globalxx(gen, seq_1_36, score_only = True)
        aligments.append(a)
    print(max(aligments), sum(aligments)/len(aligments))
# Out:
# 154.0 123.63149008020261
# 208.0 146.44765723934148
# 167.0 137.4195863233432
# 151.0 130.212325875897
# 197.0 148.19712959054453
# 133.0 112.1141831996623
# 195.0 143.19396369776277
# 127.0 93.59012241452089
# 203.0 150.77522161249473
# 195.0 142.69860700717604
# 170.0 142.09455466441537
# 180.0 131.68108906711691
# 201.0 148.41874208526804
# 171.0 140.82756437315322
# 221.0 145.67623469818489
# 172.0 138.02448290417897
# 206.0 143.05487547488391
# 170.0 137.22266779231742
# 163.0 134.83642887294218
# 205.0 150.1948079358379
# 213.0 146.90291262135923
# 193.0 139.66884761502743
# 207.0 146.5956099620093
# 193.0 144.7809202195019
# 155.0 129.42085268045588
# 211.0 142.0120303925707
# 175.0 142.2178134233854
# 212.0 145.61333896158717
# 197.0 145.03735753482482
# 190.0 148.45061207260449
# 157.0 132.17792317433515
# 151.0 128.3720979316167
# 202.0 147.7192908400169
# 220.0 146.31975517095822
# 132.0 108.78113127902068
# 208.0 140.75728155339806
# 194.0 141.60130856901645
# ...
